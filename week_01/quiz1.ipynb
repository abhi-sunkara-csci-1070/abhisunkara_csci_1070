# %% [markdown]
# ![image.png](attachment:c5d48aaa-49a7-493e-a62c-07b524940cb5.png)

# %%
My repos shown in the pdf are abhisunkara_csci_1070 and csci_1070. Week_01 is a folder under both of my repos. They are named the same. My files are shown under my folder week_01. Some of these files shown include flow_control.ipynb under week_01, and homework_1_questions.ipynb under the other week_01 folder. My homework and coding notes are under both of my folder.

# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"] 
for x in months:
    if x == "August":
        print(x, "is my birthday")
    else:
        print(x)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August is my birthday
# September
# October
# November
# December
